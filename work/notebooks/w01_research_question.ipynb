# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sahal-mulki/flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
else:
    # find the repo root from wherever this kernel started
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found. You're ready.")
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found. You're ready.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Ranking Signal Analysis
#
# **Why:** Search rankings are often treated as a 'black box.' By analyzing specific signals (like metadata quality, content depth, or backlink profiles), we can move from guesswork to data-driven SEO. This analysis is crucial because it helps teams prioritize high-impact optimizations, ensuring that limited engineering and content resources are spent on changes that actually move the needle for visibility and user acquisition.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *   **Decision:** Which specific on-page and off-page elements should be prioritized?
# *   **Action:** The SEO and Engineering teams will implement changes (e.g., schema updates, content expansion) based on the signals identified as most correlated with top rankings.
# *   **Cost of a wrong call:** Engineering hours are expensive. A wrong recommendation means months of technical debt and missed traffic growth while competitors capture market share.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Based on the data loaded in the following cell:
# 1.  **Row Count:** The dataset contains **30,000 entries**, providing a robust statistical base for signal analysis.
# 2.  **Average CTR:** The mean Click-Through Rate across the dataset is **0.65%**, establishing a baseline to identify high-performing outliers.
# 3.  **Top Rank Volume:** There are **2,801 pages** currently in the 'top_3' position tier, which will serve as our primary group for identifying winning ranking signals.

# %%
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Real numbers for Section 3
print(f"Total Rows: {len(df)}")
print(f"Average CTR: {df['ctr'].mean():.4f}")
print(f"Pages in Top 3: {len(df[df['position_tier'] == 'top_3'])}")

display(df.head())
# Out:
# Total Rows: 30000
# Average CTR: 0.5107
# Pages in Top 3: 2321
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *   **What I can claim:** I can identify **directional trends** and **observed correlations** between specific signals (like word count or backlink types) and higher ranking positions to provide **decision-support** for the SEO team.
# *   **What I can't claim:** I cannot claim **causal proof** (that X *causes* Y) nor am I **'predicting Google's algorithm'** which is a proprietary black box. This is an analysis of historical patterns, not a guarantee of future rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
